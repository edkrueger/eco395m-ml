# %%
import pandas as pd

from matplotlib import pyplot as plt

from sklearn.model_selection import train_test_split

from sklearn.tree import DecisionTreeRegressor, plot_tree
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv("data/advertising.csv", index_col="id")

# %%
X = df[["tv", "radio", "newspaper"]]
y = df["sales"].values

# %%
X_train, X_test, y_train, y_test= train_test_split(X, y, random_state=42)

# %%
model = DecisionTreeRegressor(random_state=42)

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=42)

# %%
y_hat_train = model.predict(X_train)
y_hat_test = model.predict(X_test)

# %%
train_mse = mean_squared_error(y_train, y_hat_train)
test_mse = mean_squared_error(y_test, y_hat_test)

print(train_mse)
print(test_mse)
# Out:
# 0.0
# 2.0710000000000015

# %%
plt.figure(figsize=(4, 4), dpi=1000)
plot_tree(model, feature_names=X.columns, filled=True)
# Out:
# [Text(0.41692126396648044, 0.9615384615384616, 'tv <= 108.6\nsquared_error = 26.78\nsamples = 150\nvalue = 14.305'),
#  Text(0.174231843575419, 0.8846153846153846, 'tv <= 32.75\nsquared_error = 8.044\nsamples = 50\nvalue = 9.36'),
#  Text(0.2955765537709497, 0.9230769230769231, 'True  '),
#  Text(0.04329608938547486, 0.8076923076923077, 'newspaper <= 9.0\nsquared_error = 3.873\nsamples = 20\nvalue = 6.795'),
#  Text(0.0111731843575419, 0.7307692307692307, 'tv <= 2.4\nsquared_error = 1.707\nsamples = 3\nvalue = 3.2'),
#  Text(0.00558659217877095, 0.6538461538461539, 'squared_error = 0.0\nsamples = 1\nvalue = 1.6'),
#  Text(0.01675977653631285, 0.6538461538461539, 'radio <= 6.85\nsquared_error = 0.64\nsamples = 2\nvalue = 4.0'),
#  Text(0.0111731843575419, 0.5769230769230769, 'squared_error = 0.0\nsamples = 1\nvalue = 4.8'),
#  Text(0.0223463687150838, 0.5769230769230769, 'squared_error = 0.0\nsamples = 1\nvalue = 3.2'),
#  Text(0.07541899441340782, 0.7307692307692307, 'radio <= 23.7\nsquared_error = 1.573\nsamples = 17\nvalue = 7.429'),
#  Text(0.04748603351955307, 0.6538461538461539, 'tv <= 17.95\nsquared_error = 0.577\nsamples = 9\nvalue = 6.578'),
#  Text(0.0335195530726257, 0.5769230769230769, 'tv <= 15.2\nsquared_error = 0.06\nsamples = 3\nvalue = 5.6'),
#  Text(0.027932960893854747, 0.5, 'tv <= 13.15\nsquared_error = 0.023\nsamples = 2\nvalue = 5.45'),
#  Text(0.0223463687150838, 0.4230769230769231, 'squared_error = 0.0\nsamples = 1\nvalue = 5.3'),
#  Text(0.0335195530726257, 0.4230769230769231, 'squared_error = 0.0\nsamples = 1\nvalue = 5.6'),
#  Text(0.03910614525139665, 0.5, 'squared_error = -0.0\nsamples = 1\nvalue = 5.9'),
#  Text(0.061452513966480445, 0.5769230769230769, 'tv <= 19.5\nsquared_error = 0.119\nsamples = 6\nvalue = 7.067'),
#  Text(0.05027932960893855, 0.5, 'newspaper <= 36.9\nsquared_error = 0.029\nsamples = 3\nvalue = 6.767'),
#  Text(0.0446927374301676, 0.4230769230769231, 'tv <= 19.05\nsquared_error = 0.003\nsamples = 2\nvalue = 6.65'),
#  Text(0.03910614525139665, 0.34615384615384615, 'squared_error = 0.0\nsamples = 1\nvalue = 6.7'),
#  Text(0.05027932960893855, 0.34615384615384615, 'squared_error = -0.0\nsamples = 1\nvalue = 6.6'),
#  Text(0.055865921787709494, 0.4230769230769231, 'squared_error = 0.0\nsamples = 1\nvalue = 7.0'),
#  Text(0.07262569832402235, 0.5, 'newspaper <= 23.35\nsquared_error = 0.029\nsamples = 3\nvalue = 7.367'),
#  Text(0.0670391061452514, 0.4230769230769231, 'squared_error = 0.0\nsamples = 1\nvalue = 7.6'),
#  Text(0.0782122905027933, 0.4230769230769231, 'tv <= 26.8\nsquared_error = 0.002\nsamples = 2\nvalue = 7.25'),
#  Text(0.07262569832402235, 0.34615384615384615, 'squared_error = 0.0\nsamples = 1\nvalue = 7.2'),
#  Text(0.08379888268156424, 0.34615384615384615, 'squared_error = -0.0\nsamples = 1\nvalue = 7.3'),
#  Text(0.10335195530726257, 0.6538461538461539, 'tv <= 12.95\nsquared_error = 0.959\nsamples = 8\nvalue = 8.388'),
#  Text(0.0893854748603352, 0.5769230769230769, 'radio <= 43.9\nsquared_error = 0.09\nsamples = 2\nvalue = 6.9'),
#  Text(0.08379888268156424, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 6.6'),
#  Text(0.09497206703910614, 0.5, 'squared_error = -0.0\nsamples = 1\nvalue = 7.2'),
#  Text(0.11731843575418995, 0.5769230769230769, 'radio <= 38.3\nsquared_error = 0.265\nsamples = 6\nvalue = 8.883'),
#  Text(0.10614525139664804, 0.5, 'tv <= 20.85\nsquared_error = 0.192\nsamples = 4\nvalue = 8.625'),
#  Text(0.1005586592178771, 0.4230769230769231, 'squared_error = 0.0\nsamples = 1\nvalue = 8.0'),
#  Text(0.11173184357541899, 0.4230769230769231, 'newspaper <= 54.6\nsquared_error = 0.082\nsamples = 3\nvalue = 8.833'),
#  Text(0.10614525139664804, 0.34615384615384615, 'newspaper <= 31.3\nsquared_error = 0.022\nsamples = 2\nvalue = 8.65'),
#  Text(0.1005586592178771, 0.2692307692307692, 'squared_error = 0.0\nsamples = 1\nvalue = 8.8'),
#  Text(0.11173184357541899, 0.2692307692307692, 'squared_error = -0.0\nsamples = 1\nvalue = 8.5'),
#  Text(0.11731843575418995, 0.34615384615384615, 'squared_error = 0.0\nsamples = 1\nvalue = 9.2'),
#  Text(0.12849162011173185, 0.5, 'tv <= 21.4\nsquared_error = 0.01\nsamples = 2\nvalue = 9.4'),
#  Text(0.12290502793296089, 0.4230769230769231, 'squared_error = 0.0\nsamples = 1\nvalue = 9.3'),
#  Text(0.1340782122905028, 0.4230769230769231, 'squared_error = 0.0\nsamples = 1\nvalue = 9.5'),
#  Text(0.3051675977653631, 0.8076923076923077, 'radio <= 42.3\nsquared_error = 3.515\nsamples = 30\nvalue = 11.07'),
#  Text(0.2527932960893855, 0.7307692307692307, 'radio <= 13.0\nsquared_error = 1.848\nsamples = 26\nvalue = 10.535'),
#  Text(0.19972067039106145, 0.6538461538461539, 'radio <= 6.7\nsquared_error = 0.372\nsamples = 13\nvalue = 9.585'),
#  Text(0.17039106145251395, 0.5769230769230769, 'tv <= 92.3\nsquared_error = 0.187\nsamples = 7\nvalue = 9.186'),
#  Text(0.1564245810055866, 0.5, 'newspaper <= 19.0\nsquared_error = 0.097\nsamples = 4\nvalue = 8.875'),
#  Text(0.1452513966480447, 0.4230769230769231, 'radio <= 0.4\nsquared_error = 0.09\nsamples = 2\nvalue = 9.1'),
#  Text(0.13966480446927373, 0.34615384615384615, 'squared_error = 0.0\nsamples = 1\nvalue = 8.8'),
#  Text(0.15083798882681565, 0.34615384615384615, 'squared_error = -0.0\nsamples = 1\nvalue = 9.4'),
#  Text(0.16759776536312848, 0.4230769230769231, 'newspaper <= 23.7\nsquared_error = 0.003\nsamples = 2\nvalue = 8.65'),
#  Text(0.16201117318435754, 0.34615384615384615, 'squared_error = 0.0\nsamples = 1\nvalue = 8.7'),
#  Text(0.17318435754189945, 0.34615384615384615, 'squared_error = 0.0\nsamples = 1\nvalue = 8.6'),
#  Text(0.18435754189944134, 0.5, 'newspaper <= 7.75\nsquared_error = 0.007\nsamples = 3\nvalue = 9.6'),
#  Text(0.1787709497206704, 0.4230769230769231, 'squared_error = 0.0\nsamples = 1\nvalue = 9.5'),
#  Text(0.18994413407821228, 0.4230769230769231, 'tv <= 95.7\nsquared_error = 0.003\nsamples = 2\nvalue = 9.65'),
#  Text(0.18435754189944134, 0.34615384615384615, 'squared_error = 0.0\nsamples = 1\nvalue = 9.7'),
#  Text(0.19553072625698323, 0.34615384615384615, 'squared_error = 0.0\nsamples = 1\nvalue = 9.6'),
#  Text(0.22905027932960895, 0.5769230769230769, 'tv <= 98.95\nsquared_error = 0.186\nsamples = 6\nvalue = 10.05'),
#  Text(0.22346368715083798, 0.5, 'tv <= 82.6\nsquared_error = 0.122\nsamples = 5\nvalue = 9.92'),
#  Text(0.2122905027932961, 0.4230769230769231, 'newspaper <= 21.4\nsquared_error = 0.009\nsamples = 3\nvalue = 9.767'),
#  Text(0.20670391061452514, 0.34615384615384615, 'squared_error = 0.0\nsamples = 1\nvalue = 9.9'),
#  Text(0.21787709497206703, 0.34615384615384615, 'newspaper <= 39.95\nsquared_error = 0.0\nsamples = 2\nvalue = 9.7'),
#  Text(0.2122905027932961, 0.2692307692307692, 'squared_error = 0.0\nsamples = 1\nvalue = 9.7'),
#  Text(0.22346368715083798, 0.2692307692307692, 'squared_error = 0.0\nsamples = 1\nvalue = 9.7'),
#  Text(0.2346368715083799, 0.4230769230769231, 'tv <= 93.6\nsquared_error = 0.202\nsamples = 2\nvalue = 10.15'),
#  Text(0.22905027932960895, 0.34615384615384615, 'squared_error = 0.0\nsamples = 1\nvalue = 10.6'),
#  Text(0.24022346368715083, 0.34615384615384615, 'squared_error = 0.0\nsamples = 1\nvalue = 9.7'),
#  Text(0.2346368715083799, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 10.7'),
#  Text(0.3058659217877095, 0.6538461538461539, 'tv <= 74.9\nsquared_error = 1.52\nsamples = 13\nvalue = 11.485'),
#  Text(0.28212290502793297, 0.5769230769230769, 'tv <= 51.1\nsquared_error = 0.413\nsamples = 7\nvalue = 10.629'),
#  Text(0.2681564245810056, 0.5, 'radio <= 32.25\nsquared_error = 0.206\nsamples = 5\nvalue = 10.34'),
#  Text(0.2569832402234637, 0.4230769230769231, 'newspaper <= 20.55\nsquared_error = 0.062\nsamples = 2\nvalue = 9.85'),
#  Text(0.25139664804469275, 0.34615384615384615, 'squared_error = 0.0\nsamples = 1\nvalue = 9.6'),
#  Text(0.26256983240223464, 0.34615384615384615, 'squared_error = 0.0\nsamples = 1\nvalue = 10.1'),
#  Text(0.27932960893854747, 0.4230769230769231, 'tv <= 42.0\nsquared_error = 0.036\nsamples = 3\nvalue = 10.667'),
#  Text(0.2737430167597765, 0.34615384615384615, 'squared_error = 0.0\nsamples = 2\nvalue = 10.8'),
#  Text(0.2849162011173184, 0.34615384615384615, 'squared_error = 0.0\nsamples = 1\nvalue = 10.4'),
#  Text(0.29608938547486036, 0.5, 'tv <= 65.45\nsquared_error = 0.202\nsamples = 2\nvalue = 11.35'),
#  Text(0.2905027932960894, 0.4230769230769231, 'squared_error = 0.0\nsamples = 1\nvalue = 11.8'),
#  Text(0.3016759776536313, 0.4230769230769231, 'squared_error = -0.0\nsamples = 1\nvalue = 10.9'),
#  Text(0.329608938547486, 0.5769230769230769, 'radio <= 28.15\nsquared_error = 0.958\nsamples = 6\nvalue = 12.483'),
#  Text(0.31843575418994413, 0.5, 'newspaper <= 56.15\nsquared_error = 0.355\nsamples = 4\nvalue = 11.9'),
#  Text(0.3128491620111732, 0.4230769230769231, 'radio <= 20.75\nsquared_error = 0.029\nsamples = 3\nvalue = 11.567'),
#  Text(0.30726256983240224, 0.34615384615384615, 'tv <= 101.8\nsquared_error = 0.002\nsamples = 2\nvalue = 11.45'),
#  Text(0.3016759776536313, 0.2692307692307692, 'squared_error = 0.0\nsamples = 1\nvalue = 11.4'),
#  Text(0.3128491620111732, 0.2692307692307692, 'squared_error = 0.0\nsamples = 1\nvalue = 11.5'),
#  Text(0.31843575418994413, 0.34615384615384615, 'squared_error = 0.0\nsamples = 1\nvalue = 11.8'),
#  Text(0.3240223463687151, 0.4230769230769231, 'squared_error = 0.0\nsamples = 1\nvalue = 12.9'),
#  Text(0.3407821229050279, 0.5, 'newspaper <= 28.85\nsquared_error = 0.123\nsamples = 2\nvalue = 13.65'),
#  Text(0.33519553072625696, 0.4230769230769231, 'squared_error = 0.0\nsamples = 1\nvalue = 14.0'),
#  Text(0.3463687150837989, 0.4230769230769231, 'squared_error = -0.0\nsamples = 1\nvalue = 13.3'),
#  Text(0.3575418994413408, 0.7307692307692307, 'tv <= 71.55\nsquared_error = 0.372\nsamples = 4\nvalue = 14.55'),
#  Text(0.35195530726256985, 0.6538461538461539, 'squared_error = 0.0\nsamples = 1\nvalue = 13.6'),
#  Text(0.36312849162011174, 0.6538461538461539, 'tv <= 86.05\nsquared_error = 0.096\nsamples = 3\nvalue = 14.867'),
#  Text(0.3575418994413408, 0.5769230769230769, 'newspaper <= 40.1\nsquared_error = 0.003\nsamples = 2\nvalue = 14.65'),
#  Text(0.35195530726256985, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 14.6'),
#  Text(0.36312849162011174, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 14.7'),
#  Text(0.3687150837988827, 0.5769230769230769, 'squared_error = -0.0\nsamples = 1\nvalue = 15.3'),
#  Text(0.6596106843575419, 0.8846153846153846, 'radio <= 21.2\nsquared_error = 17.811\nsamples = 100\nvalue = 16.777'),
#  Text(0.5382659741620112, 0.9230769230769231, '  False'),
#  Text(0.49196927374301674, 0.8076923076923077, 'radio <= 10.05\nsquared_error = 3.003\nsamples = 47\nvalue = 13.27'),
#  Text(0.42178770949720673, 0.7307692307692307, 'tv <= 161.1\nsquared_error = 0.838\nsamples = 23\nvalue = 11.965'),
#  Text(0.39106145251396646, 0.6538461538461539, 'tv <= 137.3\nsquared_error = 0.278\nsamples = 6\nvalue = 10.783'),
#  Text(0.37988826815642457, 0.5769230769230769, 'newspaper <= 40.0\nsquared_error = 0.062\nsamples = 3\nvalue = 11.267'),
#  Text(0.3743016759776536, 0.5, 'radio <= 5.3\nsquared_error = 0.01\nsamples = 2\nvalue = 11.1'),
#  Text(0.3687150837988827, 0.4230769230769231, 'squared_error = 0.0\nsamples = 1\nvalue = 11.2'),
#  Text(0.37988826815642457, 0.4230769230769231, 'squared_error = 0.0\nsamples = 1\nvalue = 11.0'),
#  Text(0.3854748603351955, 0.5, 'squared_error = -0.0\nsamples = 1\nvalue = 11.6'),
#  Text(0.4022346368715084, 0.5769230769230769, 'tv <= 153.2\nsquared_error = 0.027\nsamples = 3\nvalue = 10.3'),
#  Text(0.39664804469273746, 0.5, 'radio <= 1.6\nsquared_error = 0.01\nsamples = 2\nvalue = 10.2'),
#  Text(0.39106145251396646, 0.4230769230769231, 'squared_error = 0.0\nsamples = 1\nvalue = 10.1'),
#  Text(0.4022346368715084, 0.4230769230769231, 'squared_error = 0.0\nsamples = 1\nvalue = 10.3'),
#  Text(0.40782122905027934, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 10.5'),
#  Text(0.45251396648044695, 0.6538461538461539, 'radio <= 7.2\nsquared_error = 0.369\nsamples = 17\nvalue = 12.382'),
#  Text(0.4301675977653631, 0.5769230769230769, 'tv <= 203.3\nsquared_error = 0.178\nsamples = 12\nvalue = 12.083'),
#  Text(0.41899441340782123, 0.5, 'radio <= 3.3\nsquared_error = 0.02\nsamples = 3\nvalue = 11.6'),
#  Text(0.4134078212290503, 0.4230769230769231, 'squared_error = 0.0\nsamples = 1\nvalue = 11.4'),
#  Text(0.4245810055865922, 0.4230769230769231, 'squared_error = 0.0\nsamples = 2\nvalue = 11.7'),
#  Text(0.441340782122905, 0.5, 'tv <= 283.7\nsquared_error = 0.127\nsamples = 9\nvalue = 12.244'),
#  Text(0.43575418994413406, 0.4230769230769231, 'newspaper <= 46.4\nsquared_error = 0.099\nsamples = 8\nvalue = 12.175'),
#  Text(0.4301675977653631, 0.34615384615384615, 'newspaper <= 39.95\nsquared_error = 0.077\nsamples = 7\nvalue = 12.243'),
#  Text(0.4245810055865922, 0.2692307692307692, 'radio <= 3.8\nsquared_error = 0.049\nsamples = 6\nvalue = 12.167'),
#  Text(0.4134078212290503, 0.19230769230769232, 'tv <= 269.8\nsquared_error = 0.01\nsamples = 2\nvalue = 11.9'),
#  Text(0.40782122905027934, 0.11538461538461539, 'squared_error = 0.0\nsamples = 1\nvalue = 12.0'),
#  Text(0.41899441340782123, 0.11538461538461539, 'squared_error = 0.0\nsamples = 1\nvalue = 11.8'),
#  Text(0.43575418994413406, 0.19230769230769232, 'radio <= 5.15\nsquared_error = 0.015\nsamples = 4\nvalue = 12.3'),
#  Text(0.4301675977653631, 0.11538461538461539, 'tv <= 238.6\nsquared_error = 0.01\nsamples = 2\nvalue = 12.4'),
#  Text(0.4245810055865922, 0.038461538461538464, 'squared_error = 0.0\nsamples = 1\nvalue = 12.5'),
#  Text(0.43575418994413406, 0.038461538461538464, 'squared_error = 0.0\nsamples = 1\nvalue = 12.3'),
#  Text(0.441340782122905, 0.11538461538461539, 'squared_error = -0.0\nsamples = 2\nvalue = 12.2'),
#  Text(0.43575418994413406, 0.2692307692307692, 'squared_error = -0.0\nsamples = 1\nvalue = 12.7'),
#  Text(0.441340782122905, 0.34615384615384615, 'squared_error = 0.0\nsamples = 1\nvalue = 11.7'),
#  Text(0.44692737430167595, 0.4230769230769231, 'squared_error = 0.0\nsamples = 1\nvalue = 12.8'),
#  Text(0.4748603351955307, 0.5769230769230769, 'tv <= 216.35\nsquared_error = 0.096\nsamples = 5\nvalue = 13.1'),
#  Text(0.46368715083798884, 0.5, 'radio <= 9.2\nsquared_error = 0.022\nsamples = 2\nvalue = 12.75'),
#  Text(0.4581005586592179, 0.4230769230769231, 'squared_error = 0.0\nsamples = 1\nvalue = 12.9'),
#  Text(0.4692737430167598, 0.4230769230769231, 'squared_error = -0.0\nsamples = 1\nvalue = 12.6'),
#  Text(0.4860335195530726, 0.5, 'tv <= 236.1\nsquared_error = 0.009\nsamples = 3\nvalue = 13.333'),
#  Text(0.48044692737430167, 0.4230769230769231, 'squared_error = 0.0\nsamples = 2\nvalue = 13.4'),
#  Text(0.49162011173184356, 0.4230769230769231, 'squared_error = 0.0\nsamples = 1\nvalue = 13.2'),
#  Text(0.5621508379888268, 0.7307692307692307, 'tv <= 182.85\nsquared_error = 1.882\nsamples = 24\nvalue = 14.521'),
#  Text(0.5391061452513967, 0.6538461538461539, 'tv <= 151.85\nsquared_error = 0.744\nsamples = 10\nvalue = 13.17'),
#  Text(0.5195530726256983, 0.5769230769230769, 'radio <= 17.9\nsquared_error = 0.249\nsamples = 6\nvalue = 12.633'),
#  Text(0.5083798882681564, 0.5, 'newspaper <= 35.15\nsquared_error = 0.042\nsamples = 3\nvalue = 12.167'),
#  Text(0.5027932960893855, 0.4230769230769231, 'newspaper <= 28.65\nsquared_error = 0.01\nsamples = 2\nvalue = 12.3'),
#  Text(0.4972067039106145, 0.34615384615384615, 'squared_error = 0.0\nsamples = 1\nvalue = 12.2'),
#  Text(0.5083798882681564, 0.34615384615384615, 'squared_error = 0.0\nsamples = 1\nvalue = 12.4'),
#  Text(0.5139664804469274, 0.4230769230769231, 'squared_error = 0.0\nsamples = 1\nvalue = 11.9'),
#  Text(0.5307262569832403, 0.5, 'radio <= 18.8\nsquared_error = 0.02\nsamples = 3\nvalue = 13.1'),
#  Text(0.5251396648044693, 0.4230769230769231, 'squared_error = 0.0\nsamples = 1\nvalue = 12.9'),
#  Text(0.5363128491620112, 0.4230769230769231, 'tv <= 128.2\nsquared_error = 0.0\nsamples = 2\nvalue = 13.2'),
#  Text(0.5307262569832403, 0.34615384615384615, 'squared_error = 0.0\nsamples = 1\nvalue = 13.2'),
#  Text(0.5418994413407822, 0.34615384615384615, 'squared_error = 0.0\nsamples = 1\nvalue = 13.2'),
#  Text(0.5586592178770949, 0.5769230769230769, 'tv <= 178.25\nsquared_error = 0.407\nsamples = 4\nvalue = 13.975'),
#  Text(0.553072625698324, 0.5, 'newspaper <= 16.55\nsquared_error = 0.029\nsamples = 3\nvalue = 14.333'),
#  Text(0.547486033519553, 0.4230769230769231, 'squared_error = 0.0\nsamples = 1\nvalue = 14.1'),
#  Text(0.5586592178770949, 0.4230769230769231, 'tv <= 168.5\nsquared_error = 0.003\nsamples = 2\nvalue = 14.45'),
#  Text(0.553072625698324, 0.34615384615384615, 'squared_error = 0.0\nsamples = 1\nvalue = 14.5'),
#  Text(0.5642458100558659, 0.34615384615384615, 'squared_error = 0.0\nsamples = 1\nvalue = 14.4'),
#  Text(0.5642458100558659, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 12.9'),
#  Text(0.585195530726257, 0.6538461538461539, 'newspaper <= 2.0\nsquared_error = 0.461\nsamples = 14\nvalue = 15.486'),
#  Text(0.5796089385474861, 0.5769230769230769, 'squared_error = 0.0\nsamples = 1\nvalue = 17.4'),
#  Text(0.590782122905028, 0.5769230769230769, 'radio <= 12.25\nsquared_error = 0.193\nsamples = 13\nvalue = 15.338'),
#  Text(0.5754189944134078, 0.5, 'newspaper <= 13.9\nsquared_error = 0.01\nsamples = 2\nvalue = 14.9'),
#  Text(0.5698324022346368, 0.4230769230769231, 'squared_error = 0.0\nsamples = 1\nvalue = 15.0'),
#  Text(0.5810055865921788, 0.4230769230769231, 'squared_error = 0.0\nsamples = 1\nvalue = 14.8'),
#  Text(0.6061452513966481, 0.5, 'tv <= 233.8\nsquared_error = 0.185\nsamples = 11\nvalue = 15.418'),
#  Text(0.5921787709497207, 0.4230769230769231, 'radio <= 19.5\nsquared_error = 0.162\nsamples = 8\nvalue = 15.262'),
#  Text(0.5810055865921788, 0.34615384615384615, 'tv <= 227.75\nsquared_error = 0.086\nsamples = 5\nvalue = 15.02'),
#  Text(0.5754189944134078, 0.2692307692307692, 'newspaper <= 57.8\nsquared_error = 0.035\nsamples = 4\nvalue = 14.9'),
#  Text(0.5698324022346368, 0.19230769230769232, 'tv <= 188.15\nsquared_error = 0.007\nsamples = 3\nvalue = 14.8'),
#  Text(0.5642458100558659, 0.11538461538461539, 'squared_error = 0.0\nsamples = 1\nvalue = 14.7'),
#  Text(0.5754189944134078, 0.11538461538461539, 'tv <= 207.8\nsquared_error = 0.003\nsamples = 2\nvalue = 14.85'),
#  Text(0.5698324022346368, 0.038461538461538464, 'squared_error = 0.0\nsamples = 1\nvalue = 14.9'),
#  Text(0.5810055865921788, 0.038461538461538464, 'squared_error = -0.0\nsamples = 1\nvalue = 14.8'),
#  Text(0.5810055865921788, 0.19230769230769232, 'squared_error = 0.0\nsamples = 1\nvalue = 15.2'),
#  Text(0.5865921787709497, 0.2692307692307692, 'squared_error = 0.0\nsamples = 1\nvalue = 15.5'),
#  Text(0.6033519553072626, 0.34615384615384615, 'radio <= 20.8\nsquared_error = 0.029\nsamples = 3\nvalue = 15.667'),
#  Text(0.5977653631284916, 0.2692307692307692, 'squared_error = 0.0\nsamples = 1\nvalue = 15.9'),
#  Text(0.6089385474860335, 0.2692307692307692, 'radio <= 21.05\nsquared_error = 0.002\nsamples = 2\nvalue = 15.55'),
#  Text(0.6033519553072626, 0.19230769230769232, 'squared_error = 0.0\nsamples = 1\nvalue = 15.5'),
#  Text(0.6145251396648045, 0.19230769230769232, 'squared_error = -0.0\nsamples = 1\nvalue = 15.6'),
#  Text(0.6201117318435754, 0.4230769230769231, 'newspaper <= 25.1\nsquared_error = 0.009\nsamples = 3\nvalue = 15.833'),
#  Text(0.6145251396648045, 0.34615384615384615, 'squared_error = 0.0\nsamples = 2\nvalue = 15.9'),
#  Text(0.6256983240223464, 0.34615384615384615, 'squared_error = 0.0\nsamples = 1\nvalue = 15.7'),
#  Text(0.8272520949720671, 0.8076923076923077, 'tv <= 224.25\nsquared_error = 10.366\nsamples = 53\nvalue = 19.887'),
#  Text(0.732018156424581, 0.7307692307692307, 'tv <= 150.6\nsquared_error = 4.774\nsamples = 34\nvalue = 18.256'),
#  Text(0.664804469273743, 0.6538461538461539, 'radio <= 35.1\nsquared_error = 1.945\nsamples = 11\nvalue = 16.382'),
#  Text(0.6424581005586593, 0.5769230769230769, 'tv <= 121.8\nsquared_error = 0.232\nsamples = 4\nvalue = 14.975'),
#  Text(0.6368715083798883, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 14.2'),
#  Text(0.6480446927374302, 0.5, 'newspaper <= 29.4\nsquared_error = 0.042\nsamples = 3\nvalue = 15.233'),
#  Text(0.6424581005586593, 0.4230769230769231, 'tv <= 133.0\nsquared_error = 0.01\nsamples = 2\nvalue = 15.1'),
#  Text(0.6368715083798883, 0.34615384615384615, 'squared_error = 0.0\nsamples = 1\nvalue = 15.2'),
#  Text(0.6480446927374302, 0.34615384615384615, 'squared_error = -0.0\nsamples = 1\nvalue = 15.0'),
#  Text(0.6536312849162011, 0.4230769230769231, 'squared_error = 0.0\nsamples = 1\nvalue = 15.5'),
#  Text(0.6871508379888268, 0.5769230769230769, 'tv <= 128.4\nsquared_error = 1.147\nsamples = 7\nvalue = 17.186'),
#  Text(0.6703910614525139, 0.5, 'newspaper <= 57.3\nsquared_error = 0.127\nsamples = 3\nvalue = 16.2'),
#  Text(0.664804469273743, 0.4230769230769231, 'squared_error = 0.0\nsamples = 1\nvalue = 16.7'),
#  Text(0.6759776536312849, 0.4230769230769231, 'radio <= 38.75\nsquared_error = 0.002\nsamples = 2\nvalue = 15.95'),
#  Text(0.6703910614525139, 0.34615384615384615, 'squared_error = 0.0\nsamples = 1\nvalue = 15.9'),
#  Text(0.6815642458100558, 0.34615384615384615, 'squared_error = 0.0\nsamples = 1\nvalue = 16.0'),
#  Text(0.7039106145251397, 0.5, 'radio <= 44.6\nsquared_error = 0.637\nsamples = 4\nvalue = 17.925'),
#  Text(0.6983240223463687, 0.4230769230769231, 'radio <= 42.25\nsquared_error = 0.127\nsamples = 3\nvalue = 17.5'),
#  Text(0.6927374301675978, 0.34615384615384615, 'tv <= 142.45\nsquared_error = 0.002\nsamples = 2\nvalue = 17.25'),
#  Text(0.6871508379888268, 0.2692307692307692, 'squared_error = 0.0\nsamples = 1\nvalue = 17.2'),
#  Text(0.6983240223463687, 0.2692307692307692, 'squared_error = 0.0\nsamples = 1\nvalue = 17.3'),
#  Text(0.7039106145251397, 0.34615384615384615, 'squared_error = -0.0\nsamples = 1\nvalue = 18.0'),
#  Text(0.7094972067039106, 0.4230769230769231, 'squared_error = 0.0\nsamples = 1\nvalue = 19.2'),
#  Text(0.799231843575419, 0.6538461538461539, 'radio <= 41.5\nsquared_error = 3.644\nsamples = 23\nvalue = 19.152'),
#  Text(0.7604748603351955, 0.5769230769230769, 'radio <= 29.1\nsquared_error = 1.021\nsamples = 17\nvalue = 18.235'),
#  Text(0.7262569832402235, 0.5, 'tv <= 216.9\nsquared_error = 0.182\nsamples = 6\nvalue = 17.233'),
#  Text(0.7206703910614525, 0.4230769230769231, 'radio <= 22.95\nsquared_error = 0.078\nsamples = 5\nvalue = 17.08'),
#  Text(0.7150837988826816, 0.34615384615384615, 'squared_error = 0.0\nsamples = 1\nvalue = 16.6'),
#  Text(0.7262569832402235, 0.34615384615384615, 'newspaper <= 8.55\nsquared_error = 0.025\nsamples = 4\nvalue = 17.2'),
#  Text(0.7206703910614525, 0.2692307692307692, 'squared_error = 0.0\nsamples = 1\nvalue = 17.4'),
#  Text(0.7318435754189944, 0.2692307692307692, 'radio <= 26.65\nsquared_error = 0.016\nsamples = 3\nvalue = 17.133'),
#  Text(0.7262569832402235, 0.19230769230769232, 'tv <= 214.4\nsquared_error = 0.003\nsamples = 2\nvalue = 17.05'),
#  Text(0.7206703910614525, 0.11538461538461539, 'squared_error = 0.0\nsamples = 1\nvalue = 17.0'),
#  Text(0.7318435754189944, 0.11538461538461539, 'squared_error = 0.0\nsamples = 1\nvalue = 17.1'),
#  Text(0.7374301675977654, 0.19230769230769232, 'squared_error = -0.0\nsamples = 1\nvalue = 17.3'),
#  Text(0.7318435754189944, 0.4230769230769231, 'squared_error = 0.0\nsamples = 1\nvalue = 18.0'),
#  Text(0.7946927374301676, 0.5, 'tv <= 214.2\nsquared_error = 0.632\nsamples = 11\nvalue = 18.782'),
#  Text(0.7793296089385475, 0.4230769230769231, 'newspaper <= 42.35\nsquared_error = 0.402\nsamples = 8\nvalue = 18.438'),
#  Text(0.7653631284916201, 0.34615384615384615, 'radio <= 38.25\nsquared_error = 0.386\nsamples = 5\nvalue = 18.16'),
#  Text(0.7597765363128491, 0.2692307692307692, 'tv <= 188.05\nsquared_error = 0.262\nsamples = 4\nvalue = 17.95'),
#  Text(0.7486033519553073, 0.19230769230769232, 'radio <= 35.1\nsquared_error = 0.203\nsamples = 2\nvalue = 17.55'),
#  Text(0.7430167597765364, 0.11538461538461539, 'squared_error = 0.0\nsamples = 1\nvalue = 17.1'),
#  Text(0.7541899441340782, 0.11538461538461539, 'squared_error = 0.0\nsamples = 1\nvalue = 18.0'),
#  Text(0.770949720670391, 0.19230769230769232, 'tv <= 204.9\nsquared_error = 0.002\nsamples = 2\nvalue = 18.35'),
#  Text(0.7653631284916201, 0.11538461538461539, 'squared_error = 0.0\nsamples = 1\nvalue = 18.3'),
#  Text(0.776536312849162, 0.11538461538461539, 'squared_error = -0.0\nsamples = 1\nvalue = 18.4'),
#  Text(0.770949720670391, 0.2692307692307692, 'squared_error = 0.0\nsamples = 1\nvalue = 19.0'),
#  Text(0.7932960893854749, 0.34615384615384615, 'radio <= 38.35\nsquared_error = 0.087\nsamples = 3\nvalue = 18.9'),
#  Text(0.7877094972067039, 0.2692307692307692, 'radio <= 34.15\nsquared_error = 0.01\nsamples = 2\nvalue = 19.1'),
#  Text(0.7821229050279329, 0.19230769230769232, 'squared_error = 0.0\nsamples = 1\nvalue = 19.0'),
#  Text(0.7932960893854749, 0.19230769230769232, 'squared_error = -0.0\nsamples = 1\nvalue = 19.2'),
#  Text(0.7988826815642458, 0.2692307692307692, 'squared_error = -0.0\nsamples = 1\nvalue = 18.5'),
#  Text(0.8100558659217877, 0.4230769230769231, 'newspaper <= 41.5\nsquared_error = 0.087\nsamples = 3\nvalue = 19.7'),
#  Text(0.8044692737430168, 0.34615384615384615, 'squared_error = 0.0\nsamples = 1\nvalue = 20.1'),
#  Text(0.8156424581005587, 0.34615384615384615, 'newspaper <= 52.05\nsquared_error = 0.01\nsamples = 2\nvalue = 19.5'),
#  Text(0.8100558659217877, 0.2692307692307692, 'squared_error = 0.0\nsamples = 1\nvalue = 19.6'),
#  Text(0.8212290502793296, 0.2692307692307692, 'squared_error = -0.0\nsamples = 1\nvalue = 19.4'),
#  Text(0.8379888268156425, 0.5769230769230769, 'tv <= 194.95\nsquared_error = 1.946\nsamples = 6\nvalue = 21.75'),
#  Text(0.8268156424581006, 0.5, 'tv <= 174.7\nsquared_error = 0.447\nsamples = 3\nvalue = 20.5'),
#  Text(0.8212290502793296, 0.4230769230769231, 'squared_error = 0.0\nsamples = 1\nvalue = 19.6'),
#  Text(0.8324022346368715, 0.4230769230769231, 'tv <= 183.75\nsquared_error = 0.063\nsamples = 2\nvalue = 20.95'),
#  Text(0.8268156424581006, 0.34615384615384615, 'squared_error = 0.0\nsamples = 1\nvalue = 21.2'),
#  Text(0.8379888268156425, 0.34615384615384615, 'squared_error = 0.0\nsamples = 1\nvalue = 20.7'),
#  Text(0.8491620111731844, 0.5, 'radio <= 47.35\nsquared_error = 0.32\nsamples = 3\nvalue = 23.0'),
#  Text(0.8435754189944135, 0.4230769230769231, 'squared_error = 0.0\nsamples = 2\nvalue = 22.6'),
#  Text(0.8547486033519553, 0.4230769230769231, 'squared_error = 0.0\nsamples = 1\nvalue = 23.8'),
#  Text(0.922486033519553, 0.7307692307692307, 'radio <= 38.8\nsquared_error = 7.095\nsamples = 19\nvalue = 22.805'),
#  Text(0.8966480446927374, 0.6538461538461539, 'radio <= 33.25\nsquared_error = 2.756\nsamples = 10\nvalue = 20.66'),
#  Text(0.88268156424581, 0.5769230769230769, 'newspaper <= 21.6\nsquared_error = 1.076\nsamples = 6\nvalue = 19.567'),
#  Text(0.8715083798882681, 0.5, 'newspaper <= 3.65\nsquared_error = 0.102\nsamples = 4\nvalue = 20.225'),
#  Text(0.8659217877094972, 0.4230769230769231, 'squared_error = 0.0\nsamples = 1\nvalue = 20.7'),
#  Text(0.8770949720670391, 0.4230769230769231, 'radio <= 27.85\nsquared_error = 0.036\nsamples = 3\nvalue = 20.067'),
#  Text(0.8715083798882681, 0.34615384615384615, 'squared_error = 0.0\nsamples = 1\nvalue = 19.8'),
#  Text(0.88268156424581, 0.34615384615384615, 'squared_error = -0.0\nsamples = 2\nvalue = 20.2'),
#  Text(0.8938547486033519, 0.5, 'radio <= 24.2\nsquared_error = 0.423\nsamples = 2\nvalue = 18.25'),
#  Text(0.888268156424581, 0.4230769230769231, 'squared_error = 0.0\nsamples = 1\nvalue = 17.6'),
#  Text(0.8994413407821229, 0.4230769230769231, 'squared_error = 0.0\nsamples = 1\nvalue = 18.9'),
#  Text(0.9106145251396648, 0.5769230769230769, 'radio <= 37.0\nsquared_error = 0.795\nsamples = 4\nvalue = 22.3'),
#  Text(0.9050279329608939, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 23.8'),
#  Text(0.9162011173184358, 0.5, 'radio <= 37.75\nsquared_error = 0.06\nsamples = 3\nvalue = 21.8'),
#  Text(0.9106145251396648, 0.4230769230769231, 'squared_error = 0.0\nsamples = 1\nvalue = 21.5'),
#  Text(0.9217877094972067, 0.4230769230769231, 'tv <= 235.9\nsquared_error = 0.022\nsamples = 2\nvalue = 21.95'),
#  Text(0.9162011173184358, 0.34615384615384615, 'squared_error = 0.0\nsamples = 1\nvalue = 22.1'),
#  Text(0.9273743016759777, 0.34615384615384615, 'squared_error = -0.0\nsamples = 1\nvalue = 21.8'),
#  Text(0.9483240223463687, 0.6538461538461539, 'radio <= 41.75\nsquared_error = 1.121\nsamples = 9\nvalue = 25.189'),
#  Text(0.9329608938547486, 0.5769230769230769, 'newspaper <= 37.15\nsquared_error = 0.36\nsamples = 2\nvalue = 23.8'),
#  Text(0.9273743016759777, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 23.2'),
#  Text(0.9385474860335196, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 24.4'),
#  Text(0.9636871508379888, 0.5769230769230769, 'tv <= 271.9\nsquared_error = 0.63\nsamples = 7\nvalue = 25.586'),
#  Text(0.9497206703910615, 0.5, 'newspaper <= 49.5\nsquared_error = 0.32\nsamples = 3\nvalue = 25.0'),
#  Text(0.9441340782122905, 0.4230769230769231, 'squared_error = 0.0\nsamples = 2\nvalue = 25.4'),
#  Text(0.9553072625698324, 0.4230769230769231, 'squared_error = 0.0\nsamples = 1\nvalue = 24.2'),
#  Text(0.9776536312849162, 0.5, 'radio <= 42.65\nsquared_error = 0.412\nsamples = 4\nvalue = 26.025'),
#  Text(0.9664804469273743, 0.4230769230769231, 'tv <= 286.65\nsquared_error = 0.002\nsamples = 2\nvalue = 25.45'),
#  Text(0.9608938547486033, 0.34615384615384615, 'squared_error = 0.0\nsamples = 1\nvalue = 25.5'),
#  Text(0.9720670391061452, 0.34615384615384615, 'squared_error = -0.0\nsamples = 1\nvalue = 25.4'),
#  Text(0.9888268156424581, 0.4230769230769231, 'newspaper <= 56.8\nsquared_error = 0.16\nsamples = 2\nvalue = 26.6'),
#  Text(0.9832402234636871, 0.34615384615384615, 'squared_error = 0.0\nsamples = 1\nvalue = 27.0'),
#  Text(0.994413407821229, 0.34615384615384615, 'squared_error = -0.0\nsamples = 1\nvalue = 26.2')]

# %%
model.feature_importances_
# Out:
# array([0.6149656 , 0.36952678, 0.01550762])

# %%
X.columns
# Out:
# Index(['tv', 'radio', 'newspaper'], dtype='object')
