# %%
import pandas as pd

from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv("data/hitters.csv").rename(columns=lambda col: col.lower()).dropna(subset="salary")
X = df.drop("salary", axis="columns").select_dtypes("number")
y = df["salary"]

# %%
y_train, y_test, X_train, X_test, = train_test_split(y, X, random_state=42)

# %%
model_no_scale = LinearRegression()
model_scale = make_pipeline(StandardScaler(), LinearRegression(fit_intercept=False))

# %%
model_no_scale.fit(X_train, y_train)
model_scale.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('linearregression', LinearRegression(fit_intercept=False))])

# %%
model_no_scale.coef_
# Out:
# array([-1.95082071,  9.09825466,  5.3982458 , -3.29034922, -1.32505452,
#         5.41331902,  5.21174534, -0.11433449, -0.43394399, -1.31591559,
#         1.96644675,  1.00526483, -0.63946929,  0.27545148,  0.26662115,
#        -0.22426655])

# %%
mean = model_scale[0].mean_
std = model_scale[0].var_ ** (1/2)
scaled_coef = model_scale[-1].coef_

lr_coef = model_no_scale.coef_
unscaled_coef = (scaled_coef / std)

# %%
pd.DataFrame(index=X.columns, data={"scaled_coef": scaled_coef, "mean": mean, "std": std, "unscaled_coef": unscaled_coef, "lr_coef": lr_coef})
# Out:
#          scaled_coef         mean          std  unscaled_coef   lr_coef
# atbat    -277.945100   402.461929   142.475984      -1.950821 -1.950821
# hits      392.087090   106.776650    43.094759       9.098255  9.098255
# hmrun      47.829424    11.786802     8.860179       5.398246  5.398246
# runs      -81.286530    54.030457    24.704530      -3.290349 -3.290349
# rbi       -33.484344    51.685279    25.270163      -1.325055 -1.325055
# walks     113.166557    41.563452    20.905207       5.413319  5.413319
# years      24.642357     7.223350     4.728235       5.211745  5.211745
# catbat   -264.421881  2634.228426  2312.704358      -0.114334 -0.114334
# chits    -286.490505   718.258883   660.201576      -0.433944 -0.433944
# chmrun   -111.552214    70.730964    84.771557      -1.315916 -1.315916
# cruns     661.577017   359.274112   336.432713       1.966447  1.966447
# crbi      329.279296   331.979695   327.554776       1.005265  1.005265
# ...
